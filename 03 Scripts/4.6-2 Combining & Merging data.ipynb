# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#importing dataframe
path = r'C:\Users\lenovo\09-2024 CareerFoundry'
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_combined.pkl'))
df_prods = pd.read_csv(os.path.join(path, '02 Data' , 'Prepared Data' , 'products_cleaned.csv'), index_col = 0)

# %%
print(orders_products_combined.shape)
print(df_prods.shape)
#changing the type to avoid running into memory problems
#orders_products_combined['order_id'] = orders_products_combined['order_id'].astype('int32')
#orders_products_combined['user_id'] = orders_products_combined['user_id'].astype('int32')
#orders_products_combined['order_number'] = orders_products_combined['order_number'].astype('int8')
orders_products_combined['orders_day_of_week'] = orders_products_combined['orders_day_of_week'].astype('int8')
orders_products_combined['order_hour_of_day'] = orders_products_combined['order_hour_of_day'].astype('int8')
orders_products_combined['days_since_prior_order'] = orders_products_combined['days_since_prior_order'].astype('int8')
# Out:
# (30356421, 12)
# (49670, 5)

# %%
orders_products_combined['order_hour_of_day'].unique()
# Out:
# array([ 7, 12, 15,  9, 14, 16,  8, 10, 11, 19, 18, 17, 13, 20,  0, 21, 22,
#         5, 23,  4,  6,  1,  2,  3], dtype=int8)

# %%
print(orders_products_combined.head)
# Out:
# <bound method NDFrame.head of           Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0                  1             1   2398795        1             2
# 1                  1             1   2398795        1             2
# 2                  1             1   2398795        1             2
# 3                  1             1   2398795        1             2
# 4                  1             1   2398795        1             2
# ...              ...           ...       ...      ...           ...
# 30356416     3421081       3421081   2977660   206209            13
# 30356417     3421081       3421081   2977660   206209            13
# 30356418     3421081       3421081   2977660   206209            13
# 30356419     3421081       3421081   2977660   206209            13
# 30356420     3421081       3421081   2977660   206209            13
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# ...

# %%
print(df_prods.head)
# Out:
# <bound method NDFrame.head of        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# ...

# %% [markdown]
# product_id is the common key that could be used to merge/ join the 2 dataframes

# %%
#merging the new orders with the cleaned products dataframe
df_merged_large = orders_products_combined.merge(df_prods, on = 'product_id', indicator = 'match')

# %%
df_merged_large.drop('_merge', axis = 1 )
# Out:
#           Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0                  1             1   2398795        1             2
# 1                  2             2    473747        1             3
# 2                  3             3   2254736        1             4
# 3                  4             4    431534        1             5
# 4                  5             5   3367565        1             6
# ...              ...           ...       ...      ...           ...
# 30323982     3360494       3360494     31526   202557            18
# 30323983     3376039       3376039   2745165   203436             2
# 30323984     3388472       3388472    850996   204229            12
# 30323985     3392718       3392718   2550789   204472             6
# 30323986     3395727       3395727   2518919   204641            10
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          3                  7                      15
# ...

# %%
# export data as pickle
df_merged_large.to_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'ords_prods_merge.pkl'))
